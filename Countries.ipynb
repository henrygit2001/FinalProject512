# %%
import pandas as pd
import altair as alt
import numpy as np

# %%
data = pd.read_csv('world-data-2023.csv')
#keep = data.loc[:0, 'Agricultural Land( %)':'Unemployment rate'].columns
keep = ['Density\r\n(P/Km2)','Population','GDP','Agricultural Land( %)','Forested Area (%)']
data = data.dropna(axis=0,subset = keep)
data.head(10)
# Out:
#                Country Density\r\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 0          Afghanistan                 60           AF                58.10%
# 1              Albania                105           AL                43.10%
# 2              Algeria                 18           DZ                17.40%
# 3              Andorra                164           AD                40.00%
# 4               Angola                 26           AO                47.50%
# 5  Antigua and Barbuda                223           AG                20.50%
# 6            Argentina                 17           AR                54.30%
# 7              Armenia                104           AM                58.90%
# 8            Australia                  3           AU                48.20%
# 9              Austria                109           AT                32.40%
#
#   Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 0        652,230           323,000       32.49          93.0
# 1         28,748             9,000       11.78         355.0
# 2      2,381,741           317,000       24.28         213.0
# 3            468               NaN        7.20         376.0
# 4      1,246,700           117,000       40.73         244.0
# 5            443                 0       15.33           1.0
# 6      2,780,400           105,000       17.02          54.0
# 7         29,743            49,000       13.99         374.0
# 8      7,741,220            58,000       12.60          61.0
# 9         83,871            21,000        9.70          43.0
#
#        Capital/Major City Co2-Emissions  ... Out of pocket health expenditure  \
# 0                   Kabul         8,672  ...                           78.40%
# 1                  Tirana         4,536  ...                           56.90%
# 2                 Algiers       150,006  ...                           28.10%
# 3        Andorra la Vella           469  ...                           36.40%
# 4                  Luanda        34,693  ...                           33.40%
# 5  St. John's, Saint John           557  ...                           24.30%
# 6            Buenos Aires       201,348  ...                           17.60%
# 7                 Yerevan         5,156  ...                           81.60%
# 8                Canberra       375,908  ...                           19.60%
# 9                  Vienna        61,448  ...                           17.90%
#
#   Physicians per thousand  Population  \
# 0                    0.28  38,041,754
# 1                    1.20   2,854,191
# 2                    1.72  43,053,054
# 3                    3.33      77,142
# 4                    0.21  31,825,295
# 5                    2.76      97,118
# 6                    3.96  44,938,712
# 7                    4.40   2,957,731
# 8                    3.68  25,766,605
# 9                    5.17   8,877,067
#
#    Population: Labor force participation (%) Tax revenue (%) Total tax rate  \
# 0                                     48.90%           9.30%         71.40%
# 1                                     55.70%          18.60%         36.60%
# 2                                     41.20%          37.20%         66.10%
# 3                                        NaN             NaN            NaN
# 4                                     77.50%           9.20%         49.10%
# 5                                        NaN          16.50%         43.00%
# 6                                     61.30%          10.10%        106.30%
# 7                                     55.60%          20.90%         22.60%
# 8                                     65.50%          23.00%         47.40%
# 9                                     60.70%          25.40%         51.40%
#
#   Unemployment rate Urban_population   Latitude   Longitude
# 0            11.12%        9,797,273  33.939110   67.709953
# 1            12.33%        1,747,593  41.153332   20.168331
# 2            11.70%       31,510,100  28.033886    1.659626
# 3               NaN           67,873  42.506285    1.521801
# 4             6.89%       21,061,025 -11.202692   17.873887
# 5               NaN           23,800  17.060816  -61.796428
# 6             9.79%       41,339,571 -38.416097  -63.616672
# 7            16.99%        1,869,848  40.069099   45.038189
# 8             5.27%       21,844,756 -25.274398  133.775136
# 9             4.67%        5,194,416  47.516231   14.550072
#
# [10 rows x 35 columns]

# %%
data.rename(columns={'Density\r\n(P/Km2)': 'PopulationDensity'}, inplace=True)
data.rename(columns={'Forested Area (%)': 'ForestedArea'}, inplace=True)

# %%
data.head()
# Out:
#        Country PopulationDensity Abbreviation Agricultural Land( %)  \
# 0  Afghanistan                60           AF                58.10%
# 1      Albania               105           AL                43.10%
# 2      Algeria                18           DZ                17.40%
# 3      Andorra               164           AD                40.00%
# 4       Angola                26           AO                47.50%
#
#   Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 0        652,230           323,000       32.49          93.0
# 1         28,748             9,000       11.78         355.0
# 2      2,381,741           317,000       24.28         213.0
# 3            468               NaN        7.20         376.0
# 4      1,246,700           117,000       40.73         244.0
#
#   Capital/Major City Co2-Emissions  ... Out of pocket health expenditure  \
# 0              Kabul         8,672  ...                           78.40%
# 1             Tirana         4,536  ...                           56.90%
# 2            Algiers       150,006  ...                           28.10%
# 3   Andorra la Vella           469  ...                           36.40%
# 4             Luanda        34,693  ...                           33.40%
#
#   Physicians per thousand  Population  \
# 0                    0.28  38,041,754
# 1                    1.20   2,854,191
# 2                    1.72  43,053,054
# 3                    3.33      77,142
# 4                    0.21  31,825,295
#
#    Population: Labor force participation (%) Tax revenue (%) Total tax rate  \
# 0                                     48.90%           9.30%         71.40%
# 1                                     55.70%          18.60%         36.60%
# 2                                     41.20%          37.20%         66.10%
# 3                                        NaN             NaN            NaN
# 4                                     77.50%           9.20%         49.10%
#
#   Unemployment rate Urban_population   Latitude  Longitude
# 0            11.12%        9,797,273  33.939110  67.709953
# 1            12.33%        1,747,593  41.153332  20.168331
# 2            11.70%       31,510,100  28.033886   1.659626
# 3               NaN           67,873  42.506285   1.521801
# 4             6.89%       21,061,025 -11.202692  17.873887
#
# [5 rows x 35 columns]

# %%
print(data.shape)
# Out:
# (188, 35)

# %%
print(data.columns.tolist())
# Out:
# ['Country', 'PopulationDensity', 'Abbreviation', 'Agricultural Land( %)', 'Land Area(Km2)', 'Armed Forces size', 'Birth Rate', 'Calling Code', 'Capital/Major City', 'Co2-Emissions', 'CPI', 'CPI Change (%)', 'Currency-Code', 'Fertility Rate', 'ForestedArea', 'Gasoline Price', 'GDP', 'Gross primary education enrollment (%)', 'Gross tertiary education enrollment (%)', 'Infant mortality', 'Largest city', 'Life expectancy', 'Maternal mortality ratio', 'Minimum wage', 'Official language', 'Out of pocket health expenditure', 'Physicians per thousand', 'Population', 'Population: Labor force participation (%)', 'Tax revenue (%)', 'Total tax rate', 'Unemployment rate', 'Urban_population', 'Latitude', 'Longitude']

# %%
data['Population'] = data['Population'].str.replace(',', '').astype(float)

data['PopulationDensity'] = data['PopulationDensity'].str.replace(',', '').astype(float)
# data['Birth Rate'] = data['Birth Rate'].str.replace(',', '').astype(float)
data['GDP'] = data['GDP'].str.replace(',', '').str.replace('$', '').astype(float)
data['Agricultural Land( %)'] = data['Agricultural Land( %)'].str.replace(',', '').str.replace('%', '').astype(float)
data['ForestedArea'] = data['ForestedArea'].str.replace(',', '').str.replace('%', '').astype(float)
data['Armed Forces size'] = data['Armed Forces size'].str.replace(',', '').str.replace('%', '').astype(float)

# %%
data['PopulationDensity']
# Out:
# 0       60.0
# 1      105.0
# 2       18.0
# 3      164.0
# 4       26.0
#        ...
# 190     32.0
# 191    314.0
# 192     56.0
# 193     25.0
# 194     38.0
# Name: PopulationDensity, Length: 188, dtype: float64

# %%
brush = alt.selection_interval(
    encodings=['x'] # limit selection to x-axis (year) values
)

brush2 = alt.selection_interval(
    encodings=['x'] # limit selection to x-axis (year) values
)

# dynamic query histogram
birth_rate = alt.Chart(data).mark_bar().add_params(
    brush
).encode(
    alt.X('ForestedArea:Q', title='Forested Area (%)'),
    alt.Y('count():Q', title=None)
).properties(
    width=650,
    height=50
)

agricultural_land = alt.Chart(data).mark_bar().add_params(
    brush2
).encode(
    alt.X('Agricultural Land( %):Q', title='Agricultural Land (%)'),
    alt.Y('count():Q', title=None)
).properties(
    width=650,
    height=50
)

# scatter plot, modify opacity based on selection
countries = alt.Chart(data).mark_circle().encode(
    x='PopulationDensity:Q',
    y='Birth Rate:Q',
    tooltip='Country:N',
    opacity=alt.condition(brush, alt.value(0.75), alt.value(0.20)),
    fillOpacity=alt.condition(brush2, alt.value(0.75), alt.value(0.20))
).properties(
    width=650,
    height=400
)

alt.vconcat(countries, birth_rate, agricultural_land).properties(spacing=10)
# Out:
# alt.VConcatChart(...)

# %%
brush = alt.selection_interval(
    encodings=['x'] # limit selection to x-axis (year) values
)

brush2 = alt.selection_interval(
    encodings=['x'] # limit selection to x-axis (year) values
)

# dynamic query histogram
birth_rate = alt.Chart(data).mark_bar().add_params(
    brush
).encode(
    alt.X('ForestedArea:Q', title='Forested Area (%)'),
    alt.Y('count():Q', title=None)
).properties(
    width=650,
    height=50
)

agricultural_land = alt.Chart(data).mark_bar().add_params(
    brush2
).encode(
    alt.X('Agricultural Land( %):Q', title='Agricultural Land (%)'),
    alt.Y('count():Q', title=None)
).properties(
    width=650,
    height=50
)

# scatter plot, modify opacity based on selection
countries = alt.Chart(data).mark_circle().encode(
    x='GDP:Q',
    y='Armed Forces size:Q',
    tooltip='Country:N',
    opacity=alt.condition(brush, alt.value(0.75), alt.value(0.20)),
    fillOpacity=alt.condition(brush2, alt.value(0.75), alt.value(0.20))
).properties(
    width=650,
    height=400
)

alt.vconcat(countries, birth_rate, agricultural_land).properties(spacing=10)
# Out:
# alt.VConcatChart(...)

# %%
gap = pd.read_csv('gdp_pcap.csv')
gap = gap.melt(id_vars=['country'], var_name="Year", value_name='GDPpc')

gap2 = pd.read_csv('at_least_basic_sanitation_overall_access_percent.csv')
gap2 = gap2.melt(id_vars=['country'], var_name="Year", value_name='Sanitation')

gap3 = pd.read_csv('pop_number.csv')
gap3.columns = gap3.columns.str.replace('name', 'country')
gap3.columns = gap3.columns.str.replace('time', 'Year')

region = pd.read_csv('Data Geographies - v2 - by Gapminder - list-of-countries-etc.csv')
region.columns = region.columns.str.replace('name', 'country')

gapcombo = pd.merge(gap, gap2, on=['country','Year'])#,how='outer')
gapcombo['Year'] = gapcombo['Year'].astype('int64')
gapcombo = pd.merge(gapcombo, gap3, on=['country','Year'])#,how='outer')
gapcombo = pd.merge(gapcombo, region, on=['country'])

gapcombo.head(20)
#gap2.info()
# Out:
#         country  Year GDPpc  Sanitation geo_x  Population geo_y four_regions  \
# 0   Afghanistan  2000   794        21.0   afg  19542982.0   afg         asia
# 1   Afghanistan  2001   775        21.0   afg  19688632.0   afg         asia
# 2   Afghanistan  2002  1260        22.5   afg  21000256.0   afg         asia
# 3   Afghanistan  2003  1280        24.1   afg  22645130.0   afg         asia
# 4   Afghanistan  2004  1260        25.7   afg  23553551.0   afg         asia
# 5   Afghanistan  2005  1350        27.2   afg  24411191.0   afg         asia
# 6   Afghanistan  2006  1370        28.8   afg  25442944.0   afg         asia
# 7   Afghanistan  2007  1540        30.5   afg  25903301.0   afg         asia
# 8   Afghanistan  2008  1570        32.1   afg  26427199.0   afg         asia
# 9   Afghanistan  2009  1830        33.8   afg  27385307.0   afg         asia
# 10  Afghanistan  2010  2030        35.5   afg  28189672.0   afg         asia
# 11  Afghanistan  2011  1960        37.2   afg  29249157.0   afg         asia
# 12  Afghanistan  2012  2120        38.9   afg  30466479.0   afg         asia
# 13  Afghanistan  2013  2170        40.6   afg  31541209.0   afg         asia
# 14  Afghanistan  2014  2140        42.3   afg  32716210.0   afg         asia
# 15  Afghanistan  2015  2110        44.0   afg  33753499.0   afg         asia
# 16  Afghanistan  2016  2100        45.7   afg  34636207.0   afg         asia
# 17  Afghanistan  2017  2100        47.5   afg  35643418.0   afg         asia
# 18  Afghanistan  2018  2060        49.2   afg  36686784.0   afg         asia
# 19  Afghanistan  2019  2080        51.0   afg  37769499.0   afg         asia
#
#    eight_regions six_regions members_oecd_g77  Latitude  Longitude  \
# 0      asia_west  south_asia              g77      33.0       66.0
# 1      asia_west  south_asia              g77      33.0       66.0
# 2      asia_west  south_asia              g77      33.0       66.0
# 3      asia_west  south_asia              g77      33.0       66.0
# 4      asia_west  south_asia              g77      33.0       66.0
# 5      asia_west  south_asia              g77      33.0       66.0
# 6      asia_west  south_asia              g77      33.0       66.0
# 7      asia_west  south_asia              g77      33.0       66.0
# 8      asia_west  south_asia              g77      33.0       66.0
# 9      asia_west  south_asia              g77      33.0       66.0
# 10     asia_west  south_asia              g77      33.0       66.0
# 11     asia_west  south_asia              g77      33.0       66.0
# 12     asia_west  south_asia              g77      33.0       66.0
# 13     asia_west  south_asia              g77      33.0       66.0
# 14     asia_west  south_asia              g77      33.0       66.0
# 15     asia_west  south_asia              g77      33.0       66.0
# 16     asia_west  south_asia              g77      33.0       66.0
# 17     asia_west  south_asia              g77      33.0       66.0
# 18     asia_west  south_asia              g77      33.0       66.0
# 19     asia_west  south_asia              g77      33.0       66.0
#
#    UN member since World bank region World bank, 4 income groups 2017  \
# 0       19/11/1946        South Asia                       Low income
# 1       19/11/1946        South Asia                       Low income
# 2       19/11/1946        South Asia                       Low income
# 3       19/11/1946        South Asia                       Low income
# 4       19/11/1946        South Asia                       Low income
# 5       19/11/1946        South Asia                       Low income
# 6       19/11/1946        South Asia                       Low income
# 7       19/11/1946        South Asia                       Low income
# 8       19/11/1946        South Asia                       Low income
# 9       19/11/1946        South Asia                       Low income
# 10      19/11/1946        South Asia                       Low income
# 11      19/11/1946        South Asia                       Low income
# 12      19/11/1946        South Asia                       Low income
# 13      19/11/1946        South Asia                       Low income
# 14      19/11/1946        South Asia                       Low income
# 15      19/11/1946        South Asia                       Low income
# 16      19/11/1946        South Asia                       Low income
# 17      19/11/1946        South Asia                       Low income
# 18      19/11/1946        South Asia                       Low income
# 19      19/11/1946        South Asia                       Low income
#
#    World bank, 3 income groups 2017                 UNHCR
# 0                        Low income  Asia and the Pacific
# 1                        Low income  Asia and the Pacific
# 2                        Low income  Asia and the Pacific
# 3                        Low income  Asia and the Pacific
# 4                        Low income  Asia and the Pacific
# 5                        Low income  Asia and the Pacific
# 6                        Low income  Asia and the Pacific
# 7                        Low income  Asia and the Pacific
# 8                        Low income  Asia and the Pacific
# 9                        Low income  Asia and the Pacific
# 10                       Low income  Asia and the Pacific
# 11                       Low income  Asia and the Pacific
# 12                       Low income  Asia and the Pacific
# 13                       Low income  Asia and the Pacific
# 14                       Low income  Asia and the Pacific
# 15                       Low income  Asia and the Pacific
# 16                       Low income  Asia and the Pacific
# 17                       Low income  Asia and the Pacific
# 18                       Low income  Asia and the Pacific
# 19                       Low income  Asia and the Pacific

# %%
slider = alt.binding_range(min=2000, max=2022, step=1, name='Year ')
selector = alt.selection_point(
    name="SelectorName",
    fields=['Year'],
    bind=slider,
    value=[{'Year': 2001}]
)

graph = alt.Chart(gapcombo).mark_circle().encode(
    x='GDPpc:Q',
    y='Sanitation:Q',
    tooltip='country:N',
    size='Population:Q',
    color='World bank region:N' # many other choices
    #opacity=alt.condition(brush, alt.value(0.75), alt.value(0.20)),
    #fillOpacity=alt.condition(brush2, alt.value(0.75), alt.value(0.20))
).add_params(
    selector
).transform_filter(
    selector
).properties(
    width=650,
    height=400
)

graph
# Out:
# alt.Chart(...)
